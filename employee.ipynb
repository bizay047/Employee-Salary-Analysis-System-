# %%
import os
print(os.getcwd())
# Out:
# C:\Users\KIIT0001

# %%
import pandas as pd

df = pd.read_csv("C:/Users/KIIT0001/Desktop/employee_data.csv")
print(df.head())
# Out:
#    emp_id    name department  experience  salary    city
# 0     101    Anil         IT           5   60000    Pune
# 1     102  Sunita         HR           7   55000  Mumbai
# 2     103   Rohit         IT           3   45000    Pune
# 3     104    Neha    Finance           8   70000  Nagpur
# 4     105    Ajay         HR           2   35000  Mumbai

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      30 non-null     int64
#  1   name        30 non-null     object
#  2   department  30 non-null     object
#  3   experience  30 non-null     int64
#  4   salary      30 non-null     int64
#  5   city        30 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 1.5+ KB

# %%
import matplotlib.pyplot as plt

print("Average Salary:", df["salary"].mean())

print("\nHighest Paid Employee:")
print(df[df["salary"] == df["salary"].max()])

print("\nDepartment-wise Salary:")
print(df.groupby("department")["salary"].mean())

plt.hist(df["salary"])
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

df.groupby("department")["salary"].mean().plot(kind='bar')
plt.title("Department-wise Salary")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.show()

plt.scatter(df["experience"], df["salary"])
plt.title("Experience vs Salary")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()
# Out:
# Average Salary: 59700.0
#
# Highest Paid Employee:
#     emp_id   name department  experience  salary    city
# 28     129  Harsh         HR          10   95000  Mumbai
#
# Department-wise Salary:
# department
# Finance    63300.0
# HR         55200.0
# IT         60600.0
# Name: salary, dtype: float64
